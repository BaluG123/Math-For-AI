# %% [markdown]
# # Module 10 Exercises: Numerical Methods & Computational Math
#
# **Difficulty Levels**: 🟢 Basic | 🔵 Intermediate | 🔴 Advanced/AI-Applied

# %% [markdown]
# ### 1. 🟢 Floating-Point Machine Epsilon
# Write a loop to find the smallest positive float $e$ such that $1.0 + e \ne 1.0$ in 64-bit precision (machine epsilon). Compare with `np.finfo(float).eps`.

# %%
# Your code here

# %% [markdown]
# ### 2. 🟢 FP16 Underflow Demonstration
# Show a practical example in NumPy where FP16 representation leads to underflow or overflow, and how to fix it by casting or scaling.

# %%
# Your code here

# %% [markdown]
# ### 3. 🟢 Condition Number Calculation
# Given a matrix $A = \begin{bmatrix} 10 & 7 \\ 8 & 5.99 \end{bmatrix}$, find its L1 condition number using NumPy.

# %%
# Your code here

# %% [markdown]
# ### 4. 🔵 Log-Sum-Exp Derivation
# Prove mathematically that $\log \sum_i e^{x_i} = c + \log \sum_i e^{x_i - c}$ for any constant $c$.

# %%
# Your proof here

# %% [markdown]
# ### 5. 🔵 Stable Softmax Implementation
# Implement a numerically stable softmax function that can handle vectors like $\mathbf{z} = [1000, 1000, 1000]^T$ or $\mathbf{z} = [-1000, -1000, -1000]^T$ without producing `nan` or `0` for all entries.

# %%
# Your code here

# %% [markdown]
# ### 6. 🔵 Stable Sigmoid Implementation
# Explain the numerical issue with $\sigma(x) = \frac{1}{1 + e^{-x}}$ for highly negative $x$ values, and write a stable sigmoid implementation that handles both positive and negative extremes.

# %%
# Your code here

# %% [markdown]
# ### 7. 🔵 Simple Linear Congruential Generator
# Implement a Linear Congruential Generator (LCG) class in Python. Generate 1000 pseudo-random numbers and plot their distribution.

# %%
# Your code here

# %% [markdown]
# ### 8. 🔵 Power Method for Dominant Eigenvalue
# Implement the Power Method to find the dominant eigenvalue and eigenvector of $A = \begin{bmatrix} 4 & 1 \\ 1 & 3 \end{bmatrix}$.

# %%
# Your code here

# %% [markdown]
# ### 9. 🔴 Implement Conjugate Gradient from Scratch
# Write a Python function implementing the Conjugate Gradient algorithm to solve $A\mathbf{x} = \mathbf{b}$ for a positive-definite matrix $A$.

# %%
# Your code here

# %% [markdown]
# ### 10. 🔴 Monte Carlo Integration for High Dimensions
# Use Monte Carlo integration to estimate the volume of a 10-dimensional unit hypersphere. Compare the accuracy with $N=10^4, 10^5, 10^6$ samples.

# %%
# Your code here

# %% [markdown]
# ### 11. 🔴 Importance Sampling
# Explain Importance Sampling and use it to estimate the expectation $\mathbb{E}_{x \sim p}[f(x)]$ where $f(x) = x^2$ and $p(x) = \mathcal{N}(2, 1)$, using a proposal distribution $q(x) = \mathcal{N}(0, 2)$.

# %%
# Your code here

# %% [markdown]
# ### 12. 🔴 Cholesky Factorization for Jitter
# When computing Gaussian Process kernel matrices, the covariance matrix $K$ can become non-positive definite due to numerical noise. Explain what "jitter" is, and how adding it allows Cholesky factorization to proceed.

# %%
# Your code/explanation here

# %% [markdown]
# ### 13. 🔵 Euler's Method vs Runge-Kutta
# Solve the ODE $\frac{dy}{dt} = -2y$, $y(0) = 1$ using Euler's method and the RK4 (Classical Runge-Kutta) method. Compare their stability and accuracy.

# %%
# Your code here

# %% [markdown]
# ### 14. 🔴 Truncated SVD for Low-Rank Approximation
# Implement image compression using Truncated Singular Value Decomposition (SVD). Apply it to a synthetic 2D NumPy array representing a grid pattern.

# %%
# Your code here

# %% [markdown]
# ### 15. 🔴 Newton-Raphson for Logistic Regression MLE
# Implement the Newton-Raphson optimization method (Iteratively Reweighted Least Squares) to fit a binary logistic regression model on a toy dataset.

# %%
# Your code here
