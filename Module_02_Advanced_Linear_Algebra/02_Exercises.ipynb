# %% [markdown]
# # Module 2 Exercises: Advanced Linear Algebra
#
# **Difficulty Levels**: 🟢 Basic | 🔵 Intermediate | 🔴 Advanced/AI-Applied

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 🟢 Exercise 1: Compute eigenvalues and eigenvectors of $A = \begin{bmatrix} 2 & 1 \\ 1 & 2 \end{bmatrix}$. Verify $Av = \lambda v$.

# %%
# Your code here

# %% [markdown]
# ### 🟢 Exercise 2: Compute the eigendecomposition $A = Q\Lambda Q^{-1}$ for the matrix above and reconstruct $A$.

# %%
# Your code here

# %% [markdown]
# ### 🟢 Exercise 3: Compute the SVD of $M = \begin{bmatrix} 3 & 2 & 2 \\ 2 & 3 & -2 \end{bmatrix}$. Verify $M = U\Sigma V^T$.

# %%
# Your code here

# %% [markdown]
# ### 🟢 Exercise 4: Check if these matrices are positive definite by examining their eigenvalues:
# $$A = \begin{bmatrix} 5 & 2 \\ 2 & 3 \end{bmatrix}, \quad B = \begin{bmatrix} 1 & 4 \\ 4 & 1 \end{bmatrix}$$

# %%
# Your code here

# %% [markdown]
# ### 🟢 Exercise 5: Compute the QR decomposition of $A = \begin{bmatrix} 1 & 1 & 0 \\ 1 & 0 & 1 \\ 0 & 1 & 1 \end{bmatrix}$. Verify $Q$ is orthogonal.

# %%
# Your code here

# %% [markdown]
# ### 🔵 Exercise 6: Implement PCA from scratch
# 1. Generate 300 data points from a 2D Gaussian with mean=[2,3] and cov=[[2,1.5],[1.5,3]]
# 2. Center the data
# 3. Compute eigenvalues/eigenvectors of the covariance matrix
# 4. Project onto the first principal component
# 5. Plot: original data, principal component directions, and projected data

# %%
# Your code here

# %% [markdown]
# ### 🔵 Exercise 7: Low-Rank Approximation
# Create a 10×10 random matrix. Compute its SVD and create rank-1, rank-3, and rank-5 approximations. Compute the Frobenius norm error for each.

# %%
# Your code here

# %% [markdown]
# ### 🔵 Exercise 8: Gram-Schmidt
# Implement the Gram-Schmidt process from scratch. Apply it to these vectors:
# $v_1 = [1, 1, 0]$, $v_2 = [1, 0, 1]$, $v_3 = [0, 1, 1]$. Verify orthonormality.

# %%
# Your code here

# %% [markdown]
# ### 🔵 Exercise 9: Matrix Power via Eigendecomposition
# Compute $A^{10}$ for $A = \begin{bmatrix} 2 & 1 \\ 0 & 3 \end{bmatrix}$ using:
# 1. Direct multiplication (matrix_power)
# 2. Eigendecomposition: $A^{10} = Q \Lambda^{10} Q^{-1}$
#
# Verify they match.

# %%
# Your code here

# %% [markdown]
# ### 🔵 Exercise 10: Cholesky Decomposition
# 1. Create a 3×3 positive definite matrix $S = A^T A$ where $A$ is random
# 2. Compute the Cholesky decomposition $S = LL^T$
# 3. Use it to solve $Sx = b$ for $b = [1, 2, 3]$ (forward + backward substitution)

# %%
# Your code here

# %% [markdown]
# ### 🔴 Exercise 11: Spectral Norm and Weight Matrices
# Create 5 random 100×100 weight matrices. Compute the spectral norm of each. Show that after dividing each matrix by its spectral norm, the resulting matrices all have spectral norm = 1 (this is **spectral normalization** used in GANs).

# %%
# Your code here

# %% [markdown]
# ### 🔴 Exercise 12: Condition Number
# The condition number $\kappa(A) = \sigma_{max} / \sigma_{min}$ measures how sensitive $Ax = b$ is to perturbations.
#
# 1. Create a well-conditioned matrix (κ ≈ 1)
# 2. Create an ill-conditioned matrix (κ >> 1)
# 3. Show that solving $Ax = b$ with the ill-conditioned matrix gives inaccurate results when $b$ has tiny noise

# %%
# Your code here

# %% [markdown]
# ### 🔴 Exercise 13: Implement a Simple Recommendation System using SVD
# Create a user-item rating matrix (5 users × 4 items with some missing values). Use truncated SVD to predict the missing ratings.

# %%
# Your code here

# %% [markdown]
# ### 🔴 Exercise 14: Variance Explained in PCA
# Generate a 5-dimensional dataset (200 samples). Run PCA and:
# 1. Plot the cumulative variance explained vs. number of components
# 2. Find the minimum number of components needed to explain 95% of variance

# %%
# Your code here

# %% [markdown]
# ### 🔴 Exercise 15: Trace, Determinant, and Eigenvalues
# Prove numerically for 5 random 4×4 matrices that:
# 1. $\text{tr}(A) = \sum \lambda_i$ (trace = sum of eigenvalues)
# 2. $\det(A) = \prod \lambda_i$ (determinant = product of eigenvalues)

# %%
# Your code here
