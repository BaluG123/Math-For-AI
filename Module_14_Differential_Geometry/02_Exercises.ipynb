# %% [markdown]
# # Module 14 Exercises: Differential Geometry & Manifold Learning
#
# **Difficulty Levels**: 🟢 Basic | 🔵 Intermediate | 🔴 Advanced/AI-Applied

# %% [markdown]
# ### 1. 🟢 Stereographic Projection Chart
# Describe the stereographic projection map $\phi: S^1 \setminus \{(0, 1)\} \to \mathbb{R}$ for a unit circle. Write out the coordinate chart formulas.

# %%
# Your answer here

# %% [markdown]
# ### 2. 🟢 Rotation Vector to Rotation Matrix
# Write a Python function that implements the exponential map for $SO(3)$ (Rodrigues' Rotation Formula) taking a 3D vector $\omega$ and returning a $3 \times 3$ rotation matrix. Check orthogonality.

# %%
# Your code here

# %% [markdown]
# ### 3. 🟢 Fisher Information of a Bernoulli Distribution
# Find the Fisher Information $F(\theta)$ for a Bernoulli distribution $p(x; \theta) = \theta^x (1-\theta)^{1-x}$ analytically.

# %%
# Your derivation/code here

# %% [markdown]
# ### 4. 🔵 Tangent Vectors of a Sphere
# Given a point $p = [0, 0, 1]^T$ on the unit sphere $S^2 = \{\mathbf{x} \in \mathbb{R}^3 : \|\mathbf{x}\|^2 = 1\}$, define the tangent space $T_p S^2$ by finding two basis vectors.

# %%
# Your code/equations here

# %% [markdown]
# ### 5. 🔵 Christoffel Symbols derivation
# Explain what Christoffel symbols $\Gamma_{ij}^k$ are and write down their formula in terms of derivatives of the metric tensor $g_{ij}$.

# %%
# Your formula here

# %% [markdown]
# ### 6. 🔵 Poincaré Half-Plane Metric
# In the Poincaré half-plane model of hyperbolic geometry, the metric is $ds^2 = \frac{dx^2 + dy^2}{y^2}$ for $y > 0$. Write down the metric tensor $g_{ij}(x, y)$ as a matrix.

# %%
# Your matrix here

# %% [markdown]
# ### 7. 🔵 Fisher Information of a Univariate Gaussian
# Compute the $2 \times 2$ Fisher Information Matrix for a univariate Gaussian distribution $p(x; \mu, \sigma^2)$.

# %%
# Your derivation/code here

# %% [markdown]
# ### 8. 🔵 Lie Algebra of SO(3)
# Show that any element of the Lie algebra $\mathfrak{so}(3)$ is skew-symmetric, i.e., $A + A^T = 0$, by differentiating the orthogonality relation $R(t)R(t)^T = I$ at $t=0$.

# %%
# Your proof here

# %% [markdown]
# ### 9. 🔴 Geodesics on a Sphere
# Show that the geodesics on a unit sphere $S^2$ are great circles (intersections of the sphere with planes passing through the origin).

# %%
# Your explanation/proof here

# %% [markdown]
# ### 10. 🔴 Natural Gradient vs Gradient Descent on Gaussian variance
# Implement a toy optimization problem: minimize KL divergence to target $P^* \sim \mathcal{N}(0, 1)$ starting from $P_0 \sim \mathcal{N}(0, \sigma^2)$ where $\sigma^2$ is the parameter. Compare the updates of Euclidean gradient descent vs Natural Gradient descent.

# %%
# Your code here

# %% [markdown]
# ### 11. 🔴 T-SNE / UMAP Dimensionality Reduction Mathematics
# Explain the mathematical objectives of t-SNE and UMAP. How do they preserve local manifold structures in high-dimensional datasets?

# %%
# Your explanation here

# %% [markdown]
# ### 12. 🔴 Geodesics on the Poincaré Half-Plane
# Write a numerical solver to compute and plot the geodesic between two points $(1, 2)$ and $(5, 2)$ in the Poincaré half-plane (hyperbolic space). Check if the geodesic resembles a semi-circle.

# %%
# Your code here

# %% [markdown]
# ### 13. 🔵 Manifold Learning: Isomap Algorithm
# Explain the Isomap algorithm. How does it approximate geodesic distances on a manifold using shortest path distances on a nearest-neighbor graph?

# %%
# Your explanation here

# %% [markdown]
# ### 14. 🔴 Lie Group Integration (Euler Integration on Manifolds)
# In robotics, updating orientation via $R_{new} = R_{old} + dt \cdot \dot{R}$ violates orthogonality. Implement the proper Lie group update: $R_{new} = R_{old} \cdot \exp(\omega \cdot dt)$ where $\omega \in \mathfrak{so}(3)$.

# %%
# Your code here

# %% [markdown]
# ### 15. 🔴 Wasserstein Distance on Manifolds (Optimal Transport)
# Explain the Earth Mover's (Wasserstein-1) distance. How does it leverage manifold geometry to compare probability distributions, and why is it preferred over KL divergence in training WGANs?

# %%
# Your explanation here
