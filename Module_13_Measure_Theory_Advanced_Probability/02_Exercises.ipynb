# %% [markdown]
# # Module 13 Exercises: Measure Theory & Advanced Probability
#
# **Difficulty Levels**: 🟢 Basic | 🔵 Intermediate | 🔴 Advanced/AI-Applied

# %% [markdown]
# ### 1. 🟢 Minimum Sigma-Algebra
# Let $\Omega = \{1, 2, 3\}$. Find the smallest $\sigma$-algebra containing the set $\{1\}$.

# %%
# Your answer here

# %% [markdown]
# ### 2. 🟢 Non-measurable Set (Vitali Set)
# Explain briefly why we cannot assign a translation-invariant probability measure to every subset of $[0, 1]$ (Vitali's Paradox).

# %%
# Your explanation here

# %% [markdown]
# ### 3. 🟢 Quadratic Variation of Brownian Motion
# Simulate a Brownian motion path $W_t$ with 1000 steps from $t=0$ to $t=1$. Compute its quadratic variation $\sum (W_{t_{i+1}} - W_{t_i})^2$ and verify it is close to 1.

# %%
# Your code here

# %% [markdown]
# ### 4. 🔵 Countable Additivity Proof
# Using the axioms of a measure, prove that if $A \subseteq B$ are measurable sets, then $\mu(A) \le \mu(B)$.

# %%
# Your proof here

# %% [markdown]
# ### 5. 🔵 Lebesgue vs Riemann Integration
# Explain the conceptual difference between how Riemann and Lebesgue integration calculate the area under the function $f(x) = \mathbb{I}(x \in \mathbb{Q})$ for $x \in [0, 1]$ (where $\mathbb{Q}$ is the set of rational numbers). What are their respective values?

# %%
# Your answer here

# %% [markdown]
# ### 6. 🔵 Dominated Convergence Theorem Application
# Let $X_n \sim \text{Uniform}(0, 1/n)$. Compute $\lim_{n\to\infty} \mathbb{E}[n \mathbb{I}(X_n < 1/n)]$ and explain why we cannot swap the limit and expectation here (i.e. why DCT doesn't apply).

# %%
# Your explanation here

# %% [markdown]
# ### 7. 🔵 Radon-Nikodym Derivative of Two Gaussians
# Let $P$ be the probability measure of $\mathcal{N}(\mu, 1)$ and $Q$ be the measure of $\mathcal{N}(0, 1)$. Write down the analytical Radon-Nikodym derivative $\frac{dP}{dQ}(x)$.

# %%
# Your derivation/code verification here

# %% [markdown]
# ### 8. 🔵 Martingale Verification
# Let $X_i$ be independent random variables with mean 0. Prove that $S_n = \sum_{i=1}^n X_i$ is a martingale with respect to its natural filtration.

# %%
# Your proof here

# %% [markdown]
# ### 9. 🔴 Stochastic Integration & Itô's Lemma
# Let $W_t$ be a standard Brownian motion. Apply Itô's Lemma to find the stochastic differential of $V(W_t, t) = e^{t} \sin(W_t)$.

# %%
# Your equations here

# %% [markdown]
# ### 10. 🔴 Radon-Nikodym and Importance Sampling
# Write a Python script that computes the Radon-Nikodym derivative of a bivariate Gaussian $P \sim \mathcal{N}(\mathbf{1}, I)$ w.r.t. $Q \sim \mathcal{N}(\mathbf{0}, 2I)$. Use it to estimate $\mathbb{E}_P[\|\mathbf{x}\|^2]$ using samples from $Q$.

# %%
# Your code here

# %% [markdown]
# ### 11. 🔴 Itô Isometry Verification
# Verify the Itô Isometry $\mathbb{E}\left[ \left( \int_0^T h_t dW_t \right)^2 \right] = \mathbb{E}\left[ \int_0^T h_t^2 dt \right]$ numerically for $h_t = W_t$.

# %%
# Your code here

# %% [markdown]
# ### 12. 🔴 Girsanov's Theorem in Finance/ML
# Explain Girsanov's Theorem. How is it used to change probability measures from a real-world measure to a risk-neutral measure (in finance) or to analyze drift changes in diffusion models?

# %%
# Your explanation here

# %% [markdown]
# ### 13. 🔵 Conditional Expectation as L2 Projection
# In probability theory, the conditional expectation $\mathbb{E}[Y|X]$ is the optimal $L_2$ projection of $Y$ onto the space of $X$-measurable functions. Explain this connection and how it underlies supervised regression.

# %%
# Your explanation here

# %% [markdown]
# ### 14. 🔴 Fokker-Planck Equation
# Derive or state the Fokker-Planck (or Kolmogorov Forward) PDE that describes the evolution of the probability density $p(x, t)$ of the SDE $dx_t = b(x_t) dt + \sigma dW_t$.

# %%
# Your equations here

# %% [markdown]
# ### 15. 🔴 Doob's Martingale Convergence Theorem
# State Doob's Martingale Convergence Theorem. Why is it useful for proving the convergence of likelihood ratios and posteriors in Bayesian statistics?

# %%
# Your explanation here
