# %% [markdown]
# # Module 5 Exercises: Probability Theory
#
# **Difficulty Levels**: 🟢 Basic | 🔵 Intermediate | 🔴 Advanced/AI-Applied

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# ### 🟢 Exercise 1: Simulate 10,000 rolls of two dice. Compute P(sum=7) and compare to exact answer (6/36).

# %%
# Your code here

# %% [markdown]
# ### 🟢 Exercise 2: Compute P(A∪B) where P(A)=0.4, P(B)=0.5, P(A∩B)=0.1. Verify with simulation.

# %%
# Your code here

# %% [markdown]
# ### 🟢 Exercise 3: Compute the mean, variance, and std of 50,000 samples from Uniform(0, 10). Compare to theoretical values.

# %%
# Your code here

# %% [markdown]
# ### 🟢 Exercise 4: Verify the linearity of expectation: E[aX + bY] = aE[X] + bE[Y] with simulation.

# %%
# Your code here

# %% [markdown]
# ### 🟢 Exercise 5: Plot the PMF and CDF of a Poisson(λ=5) distribution.

# %%
# Your code here

# %% [markdown]
# ### 🔵 Exercise 6: Bayes' Theorem
# A spam filter: P(spam)=0.3, P("free"|spam)=0.8, P("free"|not spam)=0.1.
# Compute P(spam|"free").

# %%
# Your code here

# %% [markdown]
# ### 🔵 Exercise 7: Demonstrate the Central Limit Theorem using Exponential(λ=2) samples. Show that the mean of n samples approaches Normal as n grows.

# %%
# Your code here

# %% [markdown]
# ### 🔵 Exercise 8: Compute and visualize the covariance matrix and correlation matrix for 3 variables with known relationships.

# %%
# Your code here

# %% [markdown]
# ### 🔵 Exercise 9: Implement the Law of Total Probability
# Three factories produce items. Factory A (50%, 2% defect), B (30%, 3%), C (20%, 5%). Find P(defective) and P(from C | defective).

# %%
# Your code here

# %% [markdown]
# ### 🔵 Exercise 10: Show that for independent X,Y: Var(X+Y) = Var(X) + Var(Y), but for dependent X,Y it doesn't hold.

# %%
# Your code here

# %% [markdown]
# ### 🔴 Exercise 11: Bayesian Coin Flip
# You have a coin with unknown P(heads). Prior: P(heads) ~ Uniform(0,1). You flip 7 heads in 10 trials. Compute and plot the posterior distribution using Bayes' theorem (Beta distribution).

# %%
# Your code here

# %% [markdown]
# ### 🔴 Exercise 12: Monte Carlo Estimation
# Estimate π using Monte Carlo: random points in unit square, check if inside quarter circle. Plot convergence.

# %%
# Your code here

# %% [markdown]
# ### 🔴 Exercise 13: Implement a simple Naive Bayes text classifier
# Given training data of "spam" and "ham" messages (just use word counts), classify a new message.

# %%
# Your code here

# %% [markdown]
# ### 🔴 Exercise 14: Conditional Independence
# Generate X ~ N(0,1), Z ~ Bernoulli(0.5), Y = X + 2Z + noise. Show that X and Z are independent, but X and Y are not. Show X⊥Z|Y doesn't hold.

# %%
# Your code here

# %% [markdown]
# ### 🔴 Exercise 15: Convergence Rate of Sample Mean
# For Normal(5, 2): compute sample mean for N=10, 100, 1000, 10000. Repeat 1000 times each. Show that std of sample means ∝ 1/√N.

# %%
# Your code here
