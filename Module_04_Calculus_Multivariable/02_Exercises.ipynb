# %% [markdown]
# # Module 4 Exercises: Calculus — Multivariable
#
# **Difficulty Levels**: 🟢 Basic | 🔵 Intermediate | 🔴 Advanced/AI-Applied

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
x, y, z = sp.symbols('x y z')

# %% [markdown]
# ### 🟢 Exercise 1: Compute all partial derivatives of $f(x,y) = x^3y^2 + e^{xy}$

# %%
# Your code here

# %% [markdown]
# ### 🟢 Exercise 2: Compute the gradient of $f(x,y,z) = x^2 + 2y^2 + 3z^2$ and evaluate at $(1, 1, 1)$

# %%
# Your code here

# %% [markdown]
# ### 🟢 Exercise 3: Compute the directional derivative of $f(x,y) = x^2 + xy$ at $(1,2)$ in direction $\mathbf{u} = [3/5, 4/5]$

# %%
# Your code here

# %% [markdown]
# ### 🟢 Exercise 4: Verify that $\frac{\partial^2 f}{\partial x \partial y} = \frac{\partial^2 f}{\partial y \partial x}$ for $f(x,y) = \sin(x)\cos(y) + x^2y^3$

# %%
# Your code here

# %% [markdown]
# ### 🟢 Exercise 5: Compute the Hessian of $f(x,y) = x^4 + y^4 - 2x^2y^2$ and classify the critical point at $(0,0)$

# %%
# Your code here

# %% [markdown]
# ### 🔵 Exercise 6: Compute the Jacobian of $\mathbf{f}(x,y) = [x^2 - y^2, \; 2xy, \; x + y]$ at $(1, 1)$

# %%
# Your code here

# %% [markdown]
# ### 🔵 Exercise 7: Write a function to compute the numerical gradient and test it on $f(x,y,z) = x^2y + yz^3$

# %%
# Your code here

# %% [markdown]
# ### 🔵 Exercise 8: Lagrange Multipliers
# Find the maximum and minimum values of $f(x,y) = xy$ on the circle $x^2 + y^2 = 4$.

# %%
# Your code here

# %% [markdown]
# ### 🔵 Exercise 9: Find all critical points of $f(x,y) = x^3 + y^3 - 3xy$ and classify them using the Hessian

# %%
# Your code here

# %% [markdown]
# ### 🔵 Exercise 10: 2D Gradient Descent
# Implement gradient descent on $f(x,y) = (x-1)^2 + 10(y-2)^2$ (an elongated bowl).
# Start at $(0,0)$, lr=0.05, 100 steps. Plot the path on a contour plot.

# %%
# Your code here

# %% [markdown]
# ### 🔴 Exercise 11: Numerical Hessian
# Implement a function to compute the Hessian numerically using finite differences. Test on $f(x,y) = \sin(x) \cos(y) + x^2$.

# %%
# Your code here

# %% [markdown]
# ### 🔴 Exercise 12: Backpropagation from Scratch
# Implement forward and backward pass for: $L = (\sigma(w_2 \cdot \text{ReLU}(w_1 \cdot x + b_1) + b_2) - y)^2$
#
# Compute $\frac{\partial L}{\partial w_1}$, $\frac{\partial L}{\partial w_2}$, $\frac{\partial L}{\partial b_1}$, $\frac{\partial L}{\partial b_2}$ for $x=1.5, y=1.0$.

# %%
# Your code here

# %% [markdown]
# ### 🔴 Exercise 13: Jacobian of Softmax
# Compute the full Jacobian matrix $\frac{\partial \text{softmax}(z)_i}{\partial z_j}$ for $z = [1.0, 2.0, 3.0]$. Verify that each row sums to zero.

# %%
# Your code here

# %% [markdown]
# ### 🔴 Exercise 14: Gradient Descent vs Newton's Method (2D)
# Compare gradient descent and Newton's method on $f(x,y) = 100(y-x^2)^2 + (1-x)^2$ (Rosenbrock).
# Plot both trajectories on the same contour plot.

# %%
# Your code here

# %% [markdown]
# ### 🔴 Exercise 15: Change of Variables in Integration
# Convert $\iint_{\text{disk}} e^{-(x^2+y^2)} \, dA$ (disk of radius $R$) to polar coordinates and compute for $R = 1, 2, 5, \infty$.

# %%
# Your code here
