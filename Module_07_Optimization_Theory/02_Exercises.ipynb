# %% [markdown]
# # Module 7 Exercises: Optimization Theory
#
# **Difficulty Levels**: 🟢 Basic | 🔵 Intermediate | 🔴 Advanced/AI-Applied
#
# Complete the following exercises to build a deep understanding of optimization theory and its applications in machine learning.

# %% [markdown]
# ### 1. 🟢 Convexity Verification (Algebraic)
# Prove algebraically that the function $f(x) = x^2 - 4x + 5$ is convex using the definition $f(\theta x + (1-\theta)y) \le
# \theta f(x) + (1-\theta)f(y)$.

# %%
# Your code/proof here

# %% [markdown]
# ### 2. 🟢 Hessian-Based Convexity Check
# Calculate the Hessian of $f(x, y) = 2x^2 + 3y^2 - 4xy$ and determine if the function is strictly convex everywhere.

# %%
# Your code here

# %% [markdown]
# ### 3. 🟢 Gradient Descent Step Calculation
# For $f(x) = x^4$, starting at $x_0 = 2$ with learning rate $\alpha = 0.1$, compute the value of $x_1$ and $x_2$ manually (or write a simple Python script).

# %%
# Your code here

# %% [markdown]
# ### 4. 🔵 Convex Sets Proof
# Prove that if $S_1$ and $S_2$ are convex sets, then their intersection $S_1 \cap S_2$ is also a convex set.

# %%
# Your proof here

# %% [markdown]
# ### 5. 🔵 L1 vs L2 Norm Regularization Convexity
# Show that the L1-regularized objective $J_1(w) = L(w) + \lambda \|w\|_1$ and the L2-regularized objective $J_2(w) = L(w) + \lambda \|w\|_2^2$ are convex, assuming the loss function $L(w)$ is convex.

# %%
# Your proof here

# %% [markdown]
# ### 6. 🔵 Newton's Method on Quadratic Functions
# Show that Newton's method minimizes any strictly convex quadratic function $f(x) = \frac{1}{2}x^T A x - b^T x$ in exactly one step from any starting point.

# %%
# Your code/proof here

# %% [markdown]
# ### 7. 🔵 Lagrange Multipliers on Hyperplanes
# Find the point on the plane $x + 2y + 3z = 6$ that is closest to the origin $(0,0,0)$ using Lagrange multipliers.

# %%
# Your code here

# %% [markdown]
# ### 8. 🔵 KKT Conditions Verification
# Solve $\min (x-1)^2 + y^2$ subject to $y - x \ge 0$ using the KKT conditions.

# %%
# Your code here

# %% [markdown]
# ### 9. 🔴 Implement SGD with Momentum from Scratch
# Write a class or function implementing Gradient Descent with Momentum and use it to minimize the Rosenbrock function.

# %%
# Your code here

# %% [markdown]
# ### 10. 🔴 Implement Adam Optimizer from Scratch
# Write a Python function implementing the Adam optimizer. Compare its trajectory on the Beale function against standard GD.

# %%
# Your code here

# %% [markdown]
# ### 11. 🔴 Support Vector Machine Primal and Dual Formulations
# Write down the primal optimization problem of a hard-margin linear Support Vector Machine. Derivate the dual formulation using Lagrangian duality.

# %%
# Your explanation here

# %% [markdown]
# ### 12. 🔴 Convergence Rate Comparison
# Create a convex function with a high condition number (e.g., $f(x, y) = x^2 + 50y^2$) and plot the loss versus iteration for Gradient Descent with different learning rates to show the effect of conditioning.

# %%
# Your code here

# %% [markdown]
# ### 13. 🔵 Constrained Maximum Likelihood Estimation
# Find the maximum likelihood estimate of the probability of heads $\theta$ for a coin flipped $n$ times with $k$ heads, subject to the constraint $0.2 \le \theta \le 0.8$.

# %%
# Your code/equations here

# %% [markdown]
# ### 14. 🔴 K-Means Clustering as Non-Convex Optimization
# Formulate the K-Means objective function. Show why it is non-convex and how the coordinate descent algorithm (Lloyd's algorithm) optimizes it.

# %%
# Your explanation here

# %% [markdown]
# ### 15. 🔴 Line Search Strategies (Backtracking Line Search)
# Implement the Backtracking Line Search (Armijo condition) strategy to adaptively select the learning rate $\alpha_k$ in Gradient Descent, and compare it with a fixed learning rate.

# %%
# Your code here
