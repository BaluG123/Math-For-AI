# %% [markdown]
# # Module 1 Exercises: Linear Algebra Foundations
#
# Complete the following 15 exercises to solidify your understanding of vectors, matrices, and their operations.
#
# **Difficulty Levels**: 🟢 Basic | 🔵 Intermediate | 🔴 Advanced/AI-Applied

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 🟢 Exercise 1: Create Vectors
# Create the following vectors using NumPy:
# - $\mathbf{a} = [1, 2, 3, 4, 5]$
# - $\mathbf{b} = [10, 20, 30, 40, 50]$
#
# Print their shapes and compute $\mathbf{a} + \mathbf{b}$.

# %%
# Your code here

# %% [markdown]
# ### 🟢 Exercise 2: Create Matrices
# Create a 3×3 matrix $\mathbf{A}$ with values 1-9 and a 3×3 identity matrix $\mathbf{I}$.
# Verify that $\mathbf{A} \cdot \mathbf{I} = \mathbf{A}$.

# %%
# Your code here

# %% [markdown]
# ### 🟢 Exercise 3: Dot Product
# Given $\mathbf{u} = [1, 2, 3]$ and $\mathbf{v} = [4, 5, 6]$:
# 1. Compute the dot product manually (element-by-element)
# 2. Compute using `np.dot()`
# 3. Compute using the `@` operator
# 4. Verify all three give the same result

# %%
# Your code here

# %% [markdown]
# ### 🟢 Exercise 4: Transpose
# Create a 2×4 matrix and compute its transpose. Verify that $(A^T)^T = A$.

# %%
# Your code here

# %% [markdown]
# ### 🟢 Exercise 5: Matrix Multiplication Shapes
# For each pair below, determine if matrix multiplication is possible. If yes, compute it and print the result shape:
# - A (2×3) and B (3×4)
# - C (3×2) and D (3×2)
# - E (5×1) and F (1×5)

# %%
# Your code here

# %% [markdown]
# ### 🔵 Exercise 6: Determinant and Inverse
# Given $\mathbf{A} = \begin{bmatrix} 3 & 1 \\ 5 & 2 \end{bmatrix}$:
# 1. Compute the determinant by hand and with NumPy
# 2. Compute the inverse
# 3. Verify $A \cdot A^{-1} = I$

# %%
# Your code here

# %% [markdown]
# ### 🔵 Exercise 7: Solve a Linear System
# Solve the system:
# $$3x + 2y - z = 1$$
# $$2x - 2y + 4z = -2$$
# $$-x + \frac{1}{2}y - z = 0$$
#
# Use both `np.linalg.solve()` and the inverse method. Compare results.

# %%
# Your code here

# %% [markdown]
# ### 🔵 Exercise 8: Vector Norms
# Given $\mathbf{x} = [1, -2, 3, -4, 5]$:
# 1. Compute the L1 norm
# 2. Compute the L2 norm
# 3. Compute the L∞ norm
# 4. Normalize the vector to have unit L2 norm

# %%
# Your code here

# %% [markdown]
# ### 🔵 Exercise 9: Cosine Similarity
# Given three word embedding vectors (simplified):
# - `king = [0.5, 0.7, 0.1, 0.9]`
# - `queen = [0.6, 0.8, 0.1, 0.85]`
# - `apple = [0.1, 0.1, 0.9, 0.2]`
#
# Compute the cosine similarity between:
# 1. king and queen
# 2. king and apple
#
# Which pair is more similar?

# %%
# Your code here

# %% [markdown]
# ### 🔵 Exercise 10: Rank and Linear Independence
# For each matrix, compute the rank and determine if the columns are linearly independent:
#
# $$A = \begin{bmatrix} 1 & 2 & 3 \\ 4 & 5 & 6 \\ 7 & 8 & 9 \end{bmatrix} \qquad B = \begin{bmatrix} 1 & 0 & 2 \\ 0 & 1 & 3 \\ 1 & 1 & 5 \end{bmatrix} \qquad C = \begin{bmatrix} 1 & 0 & 0 \\ 0 & 2 & 0 \\ 0 & 0 & 3 \end{bmatrix}$$

# %%
# Your code here

# %% [markdown]
# ### 🔵 Exercise 11: Orthogonal Vectors
# 1. Find a vector that is orthogonal to $\mathbf{v} = [3, 4]$ (hint: their dot product must be 0)
# 2. Verify orthogonality using the dot product
# 3. Plot both vectors to visually confirm they are perpendicular

# %%
# Your code here

# %% [markdown]
# ### 🔴 Exercise 12: Rotation Matrix
# 1. Create a 2D rotation matrix for angle $\theta = 60°$
# 2. Rotate the vector $\mathbf{v} = [1, 0]$ by 60°
# 3. Verify the rotation matrix is orthogonal ($Q^TQ = I$)
# 4. Plot the original and rotated vector

# %%
# Your code here

# %% [markdown]
# ### 🔴 Exercise 13: Neural Network Forward Pass
# Implement a 2-layer neural network forward pass:
# - Input: $\mathbf{x} \in \mathbb{R}^3$ = [1.0, 2.0, 3.0]
# - Layer 1: $W_1 \in \mathbb{R}^{4 \times 3}$, $b_1 \in \mathbb{R}^4$, ReLU activation
# - Layer 2: $W_2 \in \mathbb{R}^{2 \times 4}$, $b_2 \in \mathbb{R}^2$, no activation
#
# Use random weights (seed=42). Print the output shape and values.

# %%
# Your code here

# %% [markdown]
# ### 🔴 Exercise 14: Projection
# The projection of vector $\mathbf{a}$ onto vector $\mathbf{b}$ is:
# $$\text{proj}_{\mathbf{b}}(\mathbf{a}) = \frac{\mathbf{a} \cdot \mathbf{b}}{\mathbf{b} \cdot \mathbf{b}} \mathbf{b}$$
#
# 1. Compute the projection of $\mathbf{a} = [3, 4]$ onto $\mathbf{b} = [1, 0]$
# 2. Compute the projection of $\mathbf{a} = [3, 4]$ onto $\mathbf{b} = [1, 1]$
# 3. Plot both projections

# %%
# Your code here

# %% [markdown]
# ### 🔴 Exercise 15: Determinant as Volume Scaling
# 1. Create a 2×2 matrix $A$ with determinant = 1 (area preserving)
# 2. Create a 2×2 matrix $B$ with determinant = 0 (collapses to line)
# 3. Create a 2×2 matrix $C$ with determinant = -1 (reflects)
# 4. Apply each to the unit square and visualize all 4 shapes (original + 3 transforms)

# %%
# Your code here
