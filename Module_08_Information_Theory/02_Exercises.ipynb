# %% [markdown]
# # Module 8 Exercises: Information Theory
#
# **Difficulty Levels**: 🟢 Basic | 🔵 Intermediate | 🔴 Advanced/AI-Applied
#
# Complete the following exercises to master information-theoretic concepts used in loss functions, generative modeling, and statistics.

# %% [markdown]
# ### 1. 🟢 Information Content of Card Draws
# Calculate the self-information (in bits) of drawing an Ace from a standard deck of 52 playing cards.

# %%
# Your code here

# %% [markdown]
# ### 2. 🟢 Shannon Entropy of a Uniform Distribution
# Calculate the Shannon entropy of a fair 8-sided die in bits.

# %%
# Your code here

# %% [markdown]
# ### 3. 🟢 Cross-Entropy Loss Calculation
# Given a true one-hot label vector $y = [0, 1, 0]$ and predicted probabilities $\hat{y} = [0.1, 0.7, 0.2]$, calculate the categorical cross-entropy loss (using natural log).

# %%
# Your code here

# %% [markdown]
# ### 4. 🔵 Bounds of Entropy
# Prove that the entropy of a discrete random variable $X$ with $K$ possible states is bounded by $0 \le H(X) \le \log_2(K)$.

# %%
# Your proof/explanation here

# %% [markdown]
# ### 5. 🔵 KL Divergence Non-Negativity Proof
# Use Jensen's Inequality to prove that the KL divergence $D_{KL}(P \parallel Q) \ge 0$ for any two distributions $P$ and $Q$.

# %%
# Your proof here

# %% [markdown]
# ### 6. 🔵 Mutual Information and Independence
# Show that if $X$ and $Y$ are independent random variables, their mutual information $I(X; Y) = 0$.

# %%
# Your proof/explanation here

# %% [markdown]
# ### 7. 🔵 Conditional Entropy Identity
# Using definitions of conditional and joint probabilities, prove that $H(Y|X) = H(X, Y) - H(X)$.

# %%
# Your proof here

# %% [markdown]
# ### 8. 🔵 Information Bottleneck formulation
# Explain the Information Bottleneck method. Why do we want to minimize $I(X; Z)$ while maximizing $I(Y; Z)$ in representation learning?

# %%
# Your explanation here

# %% [markdown]
# ### 9. 🔴 KL Divergence between two 1D Gaussians
# Derive the analytical formula for the KL divergence between two univariate Gaussians $P \sim \mathcal{N}(\mu_1, \sigma_1^2)$ and $Q \sim \mathcal{N}(\mu_2, \sigma_2^2)$.

# %%
# Your derivation or code verification here

# %% [markdown]
# ### 10. 🔴 Verify VAE KL Divergence Loss in Python
# Implement the analytical KL divergence between a diagonal Gaussian posterior $q(z|x) = \mathcal{N}(\mu, \text{diag}(\sigma^2))$ and standard Gaussian prior $p(z) = \mathcal{N}(0, I)$ in NumPy.

# %%
# Your code here

# %% [markdown]
# ### 11. 🔵 Joint and Conditional Entropy of a Binary Symmetric Channel
# Consider a Binary Symmetric Channel (BSC) with crossover probability $p$. Compute $H(Y|X)$ and the Channel Capacity.

# %%
# Your code/equations here

# %% [markdown]
# ### 12. 🔴 Text Processing: Entropy of a Corpus
# Given a short text corpus, compute the character-level Shannon entropy.

# %%
corpus = "the quick brown fox jumps over the lazy dog"
# Your code here

# %% [markdown]
# ### 13. 🔴 Mutual Information for Feature Selection
# Write a script that uses Mutual Information to rank features from a synthetic dataset for a classification task.

# %%
# Your code here

# %% [markdown]
# ### 14. 🔴 Jensen-Shannon Divergence
# Implement the Jensen-Shannon Divergence (JSD) from scratch and show that it is symmetric, unlike KL divergence.

# %%
# Your code here

# %% [markdown]
# ### 15. 🔴 Maximize Entropy of a Discrete Distribution with constraints
# Prove using Lagrange Multipliers that the distribution on $K$ states that maximizes Shannon entropy with no other constraints is the uniform distribution.

# %%
# Your proof here
