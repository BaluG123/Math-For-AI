# %% [markdown]
# # Module 15 Exercises: Category Theory & Abstract Algebra
#
# **Difficulty Levels**: 🟢 Basic | 🔵 Intermediate | 🔴 Advanced/AI-Applied

# %% [markdown]
# ### 1. 🟢 Abelian Groups
# Show that the set of integers $\mathbb{Z}$ under addition is an abelian group, but the set of integers under multiplication is not a group.

# %%
# Your answer here

# %% [markdown]
# ### 2. 🟢 Group Action Orbit
# Given a set of 2D points, define the group action of $SO(2)$ (rotation group) on this set. Write a Python snippet to rotate a point by 90 degrees.

# %%
# Your code here

# %% [markdown]
# ### 3. 🟢 Outer Product as Tensor Product
# Given vectors $\mathbf{a} = [1, 2]^T$ and $\mathbf{b} = [3, 4, 5]^T$, compute their tensor product $\mathbf{a} \otimes \mathbf{b}$ using NumPy.

# %%
# Your code here

# %% [markdown]
# ### 4. 🔵 Equivariance vs Invariance
# Prove mathematically that if a function $f: X \to Y$ is invariant under a group action of $G$, and $h: Y \to Z$ is any function, then $h \circ f$ is also invariant.

# %%
# Your proof here

# %% [markdown]
# ### 5. 🔵 Vector Space Axioms
# Show that the set of all functions $f: \mathbb{R} \to \mathbb{R}$ forms a vector space over the field of real numbers $\mathbb{R}$.

# %%
# Your explanation/proof here

# %% [markdown]
# ### 6. 🔵 Category axioms
# Show that the set of all matrices forms a category where objects are natural numbers $n \in \mathbb{N}$ and morphisms from $n \to m$ are $m \times n$ real matrices.

# %%
# Your explanation here

# %% [markdown]
# ### 7. 🔵 Functors in Functional Programming
# Implement a custom `List` class in Python with a `map` function. Show that it satisfies the functor identity law: `list.map(id) == list`.

# %%
# Your code here

# %% [markdown]
# ### 8. 🔵 Group Homomorphism
# Prove that the log map $\log: (\mathbb{R}^+, \times) \to (\mathbb{R}, +)$ is a group homomorphism.

# %%
# Your proof here

# %% [markdown]
# ### 9. 🔴 Permutation Invariance in GNNs
# Let $X \in \mathbb{R}^{N \times F}$ be a node feature matrix, and $A$ be the adjacency matrix. Prove that the GCN propagation function $f(A, X) = D^{-1/2} A D^{-1/2} X W$ is permutation equivariant, i.e., $f(P A P^T, P X) = P f(A, X)$ for any permutation matrix $P$.

# %%
# Your proof here

# %% [markdown]
# ### 10. 🔴 Group Equivariant CNNs (G-CNNs)
# Explain Group Equivariant CNNs. How do they extend standard translation equivariance to rotation and reflection groups?

# %%
# Your explanation here

# %% [markdown]
# ### 11. 🔴 Tensor Contraction and Einstein Notation
# Use NumPy's `np.einsum` to perform: (a) matrix multiplication $C = AB$, (b) batch matrix multiplication $C_b = A_b B_b$, and (c) tensor contraction of two 3rd order tensors $T_{ijk} S_{klm}$ over index $k$.

# %%
# Your code here

# %% [markdown]
# ### 12. 🔴 Kronecker Product in Deep Learning
# Explain the Kronecker product $A \otimes B$. How is it used in Kronecker-Factored Approximate Curvature (K-FAC) to approximate the Fisher Information Matrix for linear layers?

# %%
# Your explanation here

# %% [markdown]
# ### 13. 🔵 The Monad Laws
# State the three monad laws (Left identity, Right identity, Associativity) in functional programming. Verify them for the `Maybe` monad in Python.

# %%
# Your code/laws here

# %% [markdown]
# ### 14. 🔴 Universal Property of Tensor Product
# Explain the universal property of tensor products. How does it simplify multilinear operations in neural networks (like attention mechanisms) into standard linear operations?

# %%
# Your explanation here

# %% [markdown]
# ### 15. 🔴 Compositional Generalization in NLP
# Discuss how Category Theory (specifically monoidal categories) has been applied to analyze compositionality in natural language processing (e.g. DisCoCat models).

# %%
# Your explanation here
