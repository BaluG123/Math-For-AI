# %% [markdown]
# # Module 6 Exercises: Distributions & Statistics
#
# **Difficulty Levels**: 🟢 Basic | 🔵 Intermediate | 🔴 Advanced/AI-Applied

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# ### 🟢 Exercise 1: Plot the PMF of Binomial(n=20, p) for p = 0.2, 0.5, 0.8 on the same figure.

# %%
# Your code here

# %% [markdown]
# ### 🟢 Exercise 2: Generate 10,000 samples from N(5, 2). Compute sample mean, variance. Plot histogram vs true PDF.

# %%
# Your code here

# %% [markdown]
# ### 🟢 Exercise 3: Verify the 68-95-99.7 rule empirically with 100,000 samples from N(0,1).

# %%
# Your code here

# %% [markdown]
# ### 🟢 Exercise 4: Plot Beta distributions for (α,β) = (1,1), (2,5), (5,2), (10,10), (0.5,0.5).

# %%
# Your code here

# %% [markdown]
# ### 🟢 Exercise 5: Show that Poisson(λ) has mean = λ and variance = λ empirically for λ = 1, 5, 10.

# %%
# Your code here

# %% [markdown]
# ### 🔵 Exercise 6: MLE for Bernoulli
# Given coin flips [H,H,T,H,T,H,H,H,T,H], compute the MLE for p. Derive the formula first (hint: take derivative of log-likelihood).

# %%
# Your code here

# %% [markdown]
# ### 🔵 Exercise 7: MLE for Gaussian
# Generate 50 samples from N(3, 1.5). Compute MLE estimates for μ and σ. Plot the log-likelihood surface.

# %%
# Your code here

# %% [markdown]
# ### 🔵 Exercise 8: Generate 2D data from a multivariate Gaussian. Estimate the mean vector and covariance matrix. Plot samples with the estimated density contours.

# %%
# Your code here

# %% [markdown]
# ### 🔵 Exercise 9: Perform a t-test to check if two groups have different means. Group A: N(10, 2, n=50), Group B: N(10.5, 2, n=50).

# %%
# Your code here

# %% [markdown]
# ### 🔵 Exercise 10: Compute 95% confidence interval for the mean accuracy of a model from 25 evaluation runs.

# %%
# Your code here

# %% [markdown]
# ### 🔴 Exercise 11: Bayesian Updating
# Start with Beta(1,1) prior on a coin's bias. Update sequentially with 20 coin flips (15 heads). Plot the posterior after each flip.

# %%
# Your code here

# %% [markdown]
# ### 🔴 Exercise 12: MAP vs MLE comparison
# For N=5 samples from N(3, 1), compare MLE and MAP estimates of μ using a Gaussian prior N(0, 10) vs N(0, 0.5). Show how strong priors bias the estimate.

# %%
# Your code here

# %% [markdown]
# ### 🔴 Exercise 13: KDE (Kernel Density Estimation)
# Generate bimodal data (mixture of two Gaussians). Estimate the PDF using KDE with different bandwidths. Compare with true density.

# %%
# Your code here

# %% [markdown]
# ### 🔴 Exercise 14: Show that MSE loss = MLE under Gaussian noise.
# Given y = f(x) + ε where ε ~ N(0, σ²), show that maximizing the log-likelihood of the data is equivalent to minimizing MSE.

# %%
# Your code here

# %% [markdown]
# ### 🔴 Exercise 15: Bootstrap Confidence Intervals
# Implement bootstrap to estimate the 95% CI for the median of a skewed distribution (Exponential(2), n=50).

# %%
# Your code here
