# %% [markdown]
# # Module 3 Exercises: Calculus — Single Variable
#
# **Difficulty Levels**: 🟢 Basic | 🔵 Intermediate | 🔴 Advanced/AI-Applied

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
x = sp.Symbol('x')

# %% [markdown]
# ### 🟢 Exercise 1: Compute these limits using SymPy
# 1. $\lim_{x \to 0} \frac{\sin(3x)}{x}$
# 2. $\lim_{x \to \infty} \frac{x^2 + 1}{2x^2 - 3}$
# 3. $\lim_{x \to 0} \frac{e^x - 1 - x}{x^2}$

# %%
# Your code here

# %% [markdown]
# ### 🟢 Exercise 2: Differentiate these functions symbolically and verify numerically at $x=2$
# 1. $f(x) = 3x^4 - 2x^2 + 7$
# 2. $g(x) = \sin(x) \cdot e^x$
# 3. $h(x) = \frac{x^2}{x+1}$

# %%
# Your code here

# %% [markdown]
# ### 🟢 Exercise 3: Implement numerical differentiation
# Write functions for:
# 1. Forward difference: $f'(x) \approx \frac{f(x+h) - f(x)}{h}$
# 2. Central difference: $f'(x) \approx \frac{f(x+h) - f(x-h)}{2h}$
#
# Compare their accuracy on $f(x) = x^3$ at $x=2$ for $h = 0.1, 0.01, 0.001, 0.0001$.

# %%
# Your code here

# %% [markdown]
# ### 🟢 Exercise 4: Chain Rule Practice
# Differentiate using the chain rule (both symbolically and verify numerically):
# 1. $f(x) = \sin(x^2 + 1)$
# 2. $g(x) = e^{\cos(x)}$
# 3. $h(x) = \ln(\sin(x))$

# %%
# Your code here

# %% [markdown]
# ### 🟢 Exercise 5: Compute these integrals
# 1. $\int_0^1 x^3 \, dx$
# 2. $\int_0^{\pi} \sin(x) \, dx$
# 3. $\int_1^e \frac{1}{x} \, dx$

# %%
# Your code here

# %% [markdown]
# ### 🔵 Exercise 6: Taylor Series
# 1. Compute the 5th-order Taylor expansion of $e^x$ around $x=0$
# 2. Plot the original function and Taylor approximations of orders 1, 2, 3, 5 on $[-3, 3]$
# 3. Compute the approximation error at $x=1$ for each order

# %%
# Your code here

# %% [markdown]
# ### 🔵 Exercise 7: Find Critical Points
# For $f(x) = x^3 - 6x^2 + 9x + 1$:
# 1. Find all critical points (where $f'(x) = 0$)
# 2. Use the second derivative test to classify each
# 3. Plot the function with critical points marked

# %%
# Your code here

# %% [markdown]
# ### 🔵 Exercise 8: Sigmoid and Its Properties
# For the sigmoid function $\sigma(x) = \frac{1}{1+e^{-x}}$:
# 1. Prove symbolically that $\sigma'(x) = \sigma(x)(1-\sigma(x))$
# 2. Show that $\sigma(-x) = 1 - \sigma(x)$
# 3. Find where $\sigma'(x)$ is maximized
# 4. Plot $\sigma$, $\sigma'$, and $\sigma''$

# %%
# Your code here

# %% [markdown]
# ### 🔵 Exercise 9: Integration by Substitution
# Compute these integrals using SymPy:
# 1. $\int x e^{x^2} \, dx$
# 2. $\int \frac{\cos(x)}{1 + \sin(x)} \, dx$
# 3. $\int_0^{\infty} x e^{-x} \, dx$ (this gives $E[X]$ for Exponential distribution!)

# %%
# Your code here

# %% [markdown]
# ### 🔵 Exercise 10: Learning Rate Comparison
# Implement gradient descent on $f(x) = x^4 - 3x^3 + 2$ starting at $x=4$.
# Run with learning rates: $\alpha = 0.001, 0.01, 0.05, 0.1$.
# Plot the convergence curve (loss vs. step) for each.

# %%
# Your code here

# %% [markdown]
# ### 🔴 Exercise 11: Newton's Method
# Implement Newton's method: $x_{t+1} = x_t - \frac{f'(x_t)}{f''(x_t)}$
#
# Compare convergence speed with gradient descent on $f(x) = (x-2)^4$.

# %%
# Your code here

# %% [markdown]
# ### 🔴 Exercise 12: Softmax Derivative
# The softmax for element $i$ is: $\text{softmax}(z)_i = \frac{e^{z_i}}{\sum_j e^{z_j}}$
#
# For $z = [2.0, 1.0, 0.1]$:
# 1. Compute softmax(z)
# 2. Compute the Jacobian $\frac{\partial \text{softmax}_i}{\partial z_j}$ numerically
# 3. Verify: diagonal entries are $s_i(1-s_i)$, off-diagonal are $-s_i s_j$

# %%
# Your code here

# %% [markdown]
# ### 🔴 Exercise 13: Cross-Entropy Loss Derivative
# The cross-entropy loss: $L = -\sum_i y_i \log(\hat{y}_i)$
#
# For binary case ($y \in \{0,1\}$, $\hat{y} = \sigma(z)$):
# 1. Write $L = -[y \log \sigma(z) + (1-y) \log(1-\sigma(z))]$
# 2. Show that $\frac{\partial L}{\partial z} = \sigma(z) - y$ (beautifully simple!)
# 3. Verify numerically

# %%
# Your code here

# %% [markdown]
# ### 🔴 Exercise 14: Numerical Integration — Monte Carlo
# Estimate $\int_0^1 e^{-x^2} dx$ using:
# 1. Trapezoidal rule (N=100)
# 2. Simpson's rule (scipy)
# 3. Monte Carlo integration (N=10000 random samples)
#
# Compare all three with SymPy's exact answer.

# %%
# Your code here

# %% [markdown]
# ### 🔴 Exercise 15: Gradient Descent on a Real Loss Function
# Generate synthetic data: $y = 2x + 1 + \epsilon$ (50 points).
# Use gradient descent to learn $w$ and $b$ in $\hat{y} = wx + b$ by minimizing MSE:
# $$L(w,b) = \frac{1}{n}\sum(y_i - wx_i - b)^2$$
#
# 1. Derive $\frac{\partial L}{\partial w}$ and $\frac{\partial L}{\partial b}$
# 2. Implement gradient descent (lr=0.01, 500 steps)
# 3. Plot the learned line and loss curve

# %%
# Your code here
